# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"E:\project\Transformer\student_resource\dataset\train.csv")
df.head()
# Out:
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...   4.89
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...  13.12
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...   1.97
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...  30.34
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...  66.49

# %%
seed = 42
data = df.sample(frac=0.35, random_state=seed)
data
# Out:
#        sample_id                                    catalog_content  \
# 26837     158784  Item Name: Log Cabin Sugar Free Syrup, 24 FL O...
# 2592        4095  Item Name: Raspberry Ginseng Oolong Tea (50 te...
# 18359     172021  Item Name: Walden Farms Honey Dijon Dressing -...
# 73292     268276  Item Name: Vlasic Ovals Hamburger Dill Pickle ...
# 60127     154791  Item Name: Amoretti Premium Syrup, Grand Orang...
# ...          ...                                                ...
# 59806     172140  Item Name: Matilde Vicenzi Roma Cookie Tin - I...
# 17609      60613  Item Name: Sanpellegrino Italian Sparkling Dri...
# 42259      70383  Item Name: Big Dot of Happiness Happy Thanksgi...
# 73374      68817  Item Name: Trolli Duo Crawlers, 4.25 Ounce\r\n...
# 19766      13039  Item Name: Steaz, Tea Iced Green Unsweetened P...
#
#                                               image_link   price
# 26837  https://m.media-amazon.com/images/I/71QD2OFXqD...  12.195
# 2592   https://m.media-amazon.com/images/I/813OiT8mdJ...  38.540
# 18359  https://m.media-amazon.com/images/I/71HGx42QmU...  17.860
# 73292  https://m.media-amazon.com/images/I/71AbnhXOTA...   2.940
# 60127  https://m.media-amazon.com/images/I/61c+aTE6TY...  25.990
# ...                                                  ...     ...
# 59806  https://m.media-amazon.com/images/I/81t0eSdOvz...  33.990
# 17609  https://m.media-amazon.com/images/I/811fwHP4ZI...  41.960
# 42259  https://m.media-amazon.com/images/I/71Zs2A7pgx...  11.240
# 73374  https://m.media-amazon.com/images/I/91NYngzFLB...   3.690
# 19766  https://m.media-amazon.com/images/I/71Gxka7od2...  78.300
#
# [26250 rows x 4 columns]

# %%
from PIL import Image
import requests
from io import BytesIO
from IPython.display import display

url = df["image_link"][1]
response = requests.get(url)
img = Image.open(BytesIO(response.content))
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1200>
